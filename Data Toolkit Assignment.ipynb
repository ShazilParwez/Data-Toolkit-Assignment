# %%
#1.Demonstrate three different methods for creating identical 2D arrays in NumPy. Provide the code for each method and the final output after each method.

#Answer 1:

#Method 1: Using numpy.array()
#This method creates an array from a nested list.

import numpy as np
array1 = np.array([[1, 2, 3], [4, 5, 6]])

print("Method 1: Using numpy.array()")
print(array1)
# Out:
# Method 1: Using numpy.array()
# [[1 2 3]
#  [4 5 6]]

# %%
#Method 2: Using numpy.zeros()
#This method creates an array filled with zeros and then assigns values.

array2 = np.zeros((2, 3), dtype=int)  # Create a 2D array of zeros
array2[0] = [1, 2, 3]  # Assign values to the first row
array2[1] = [4, 5, 6]  # Assign values to the second row

print("\nMethod 2: Using numpy.zeros()")
print(array2)
# Out:
# Method 2: Using numpy.zeros()
# [[1 2 3]
#  [4 5 6]]

# %%
#Method 3: Using numpy.arange() and numpy.reshape()
#This method generates an array of values using arange() and then reshapes it.

array3 = np.arange(1, 7).reshape(2, 3)  # Create an array of numbers from 1 to 6 and reshape
print("\nMethod 3: Using numpy.arange() and reshape()")
print(array3)
# Out:
# Method 3: Using numpy.arange() and reshape()
# [[1 2 3]
#  [4 5 6]]

# %%
#2.Using the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and Reshape that ID array into a 2D array.

#Answer 2:

import numpy as np
array_1d = np.linspace(1, 10, 100)
array_2d = array_1d.reshape(10, 10)

print(array_2d)
# Out:
# [[ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#    1.54545455  1.63636364  1.72727273  1.81818182]
#  [ 1.90909091  2.          2.09090909  2.18181818  2.27272727  2.36363636
#    2.45454545  2.54545455  2.63636364  2.72727273]
#  [ 2.81818182  2.90909091  3.          3.09090909  3.18181818  3.27272727
#    3.36363636  3.45454545  3.54545455  3.63636364]
#  [ 3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#    4.27272727  4.36363636  4.45454545  4.54545455]
#  [ 4.63636364  4.72727273  4.81818182  4.90909091  5.          5.09090909
#    5.18181818  5.27272727  5.36363636  5.45454545]
#  [ 5.54545455  5.63636364  5.72727273  5.81818182  5.90909091  6.
#    6.09090909  6.18181818  6.27272727  6.36363636]
#  [ 6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#    7.          7.09090909  7.18181818  7.27272727]
#  [ 7.36363636  7.45454545  7.54545455  7.63636364  7.72727273  7.81818182
# ...

# %% [markdown]
# 3.Explain the following terms:
#
#   The difference in np.array, np.asarray and np.asanyarray.
#
#   The difference between Deep copy and shallow copy.
#
# Answer 3:
#
# #NumPy Array Functions
#
# 1. `np.array`:
#    - This function creates a new NumPy array from any input data, such as lists or tuples. Importantly, it always makes a copy of the data. If you use `np.array`, you can be sure that the new array is separate from the original input, even if that input is already an array.
#
# 2. `np.asarray`:
#    - This function also creates a NumPy array, but with a key difference: if the input is already a NumPy array, `np.asarray` will return it without making a copy. It only creates a new array when the input is a different type, like a list. This makes it more efficient when you want to convert data but avoid unnecessary copying.
#
# 3. `np.asanyarray`:
#    - This function is similar to `np.asarray`, but it goes a step further by allowing for the return of array subclasses (like matrices or masked arrays) without converting them to a base array type. This means that if you provide it with a special type of array, it will return that same type rather than changing it to a standard array.
#
# #Deep Copy vs. Shallow Copy
#
# 1. Shallow Copy:
#    - A shallow copy creates a new object but keeps references to the original nested objects. This means if you modify one of the nested objects in the shallow copy, it will also affect the original. In essence, while the outer structure is new, the inner data is shared.
#
# 2. Deep Copy:
#    - A deep copy creates a completely independent object, along with copies of all objects contained within it, no matter how deeply nested. Changes made to a deep copy do not affect the original object at all. This is useful when you need to ensure that the two objects operate independently from each other.

# %%
#4.Generate a 3×3 array with random floating-point numbers between 5 and 20. Then, round each number in the array to 2 decimal places.

#Answer 4:

import numpy as np
array_random = np.random.uniform(5, 20, (3, 3))
array_rounded = np.round(array_random, 2)

print(array_rounded)
# Out:
# [[13.77  7.74  9.27]
#  [16.44 11.29 11.8 ]
#  [ 6.81  5.13 17.11]]

# %%
#5.Create a Numpy array with random integers between 1 and 10 of shape (5, 6). After creating the array
#perform the following operations:
  #a)Extract all even integers from array.
  #b)Extract all odd integers from array.

#Answer 5:

import numpy as np

# Create a 5x6 array with random integers between 1 and 10
array_random = np.random.randint(1, 11, size=(5, 6))

print("Original Array:")
print(array_random)

# a) Extract all even integers from the array
even_integers = array_random[array_random % 2 == 0]
print("\nEven Integers:")
print(even_integers)

# b) Extract all odd integers from the array
odd_integers = array_random[array_random % 2 != 0]
print("\nOdd Integers:")
print(odd_integers)
# Out:
# Original Array:
# [[ 6  8  9  9  5  1]
#  [10  8  8  1  8  9]
#  [ 3  7  5  9  1 10]
#  [ 6  3  5  2  1  4]
#  [10  3  4  9  6  9]]
#
# Even Integers:
# [ 6  8 10  8  8  8 10  6  2  4 10  4  6]
#
# Odd Integers:
# [9 9 5 1 1 9 3 7 5 9 1 3 5 1 3 9 9]

# %%
#6.Create a 3D NumPy array of shape (3, 3, 3) containing random integers between 1 and 10. Perform the following operations:
  #a)Find the indices of the maximum values along each depth level (third axis).
  #b)Perform element-wise multiplication of between both array.

#Answer 6:

import numpy as np

# Create a 3D array of shape (3, 3, 3) with random integers between 1 and 10
array_3d = np.random.randint(1, 11, size=(3, 3, 3))

print("Original 3D Array:")
print(array_3d)

# a) Find the indices of the maximum values along each depth level (third axis)
max_indices = np.argmax(array_3d, axis=2)
print("\nIndices of Maximum Values along Depth Level (third axis):")
print(max_indices)

# b) Perform element-wise multiplication of the array with itself
elementwise_multiplication = array_3d * array_3d
print("\nElement-wise Multiplication of the Array with Itself:")
print(elementwise_multiplication)
# Out:
# Original 3D Array:
# [[[ 6  8  3]
#   [ 7  4  2]
#   [10  2  6]]
#
#  [[ 9  8  3]
#   [ 1  7  4]
#   [ 8  7 10]]
#
#  [[ 9  8  9]
#   [ 2  4  7]
#   [ 4  9  2]]]
#
# Indices of Maximum Values along Depth Level (third axis):
# [[1 0 0]
#  [0 1 2]
#  [0 2 1]]
#
# Element-wise Multiplication of the Array with Itself:
# [[[ 36  64   9]
#   [ 49  16   4]
#   [100   4  36]]
#
#  [[ 81  64   9]
#   [  1  49  16]
#   [ 64  49 100]]
#
#  [[ 81  64  81]
#   [  4  16  49]
#   [ 16  81   4]]]

# %%
#7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type. Also display the table attributes and data types of each column.

#Answer 7:

import pandas as pd

# Load the dataset from the provided URL
url = 'https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'
data = pd.read_csv(url)

# Display the initial data types of each column
print("Initial Data Types:")
print(data.dtypes)

# Clean the 'Phone' column: remove non-numeric characters and convert to numeric
data['Phone'] = data['Phone'].replace(r'\D', '', regex=True).astype(float)

# Alternatively, you can convert to int if you want whole numbers
# data['Phone'] = data['Phone'].replace(r'\D', '', regex=True).astype(int)

# Display the cleaned 'Phone' column and its data type
print("\nCleaned 'Phone' column:")
print(data['Phone'])
print("\nData Type of 'Phone' column:")
print(data['Phone'].dtype)

# Display the updated data types of each column
print("\nUpdated Data Types:")
print(data.dtypes)
# Out:
# Initial Data Types:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# Gender           object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# Salary            int64
# dtype: object
#
# Cleaned 'Phone' column:
# 0      8.571398e+09
# 1               NaN
# 2      5.997821e+09
# 3               NaN
# 4      3.904172e+13
#            ...
# 995    2.177529e+08
# 996    1.149711e+13
# 997    1.750774e+15
# 998    9.152922e+09
# 999    7.975254e+13
# Name: Phone, Length: 1000, dtype: float64
#
# Data Type of 'Phone' column:
# float64
#
# Updated Data Types:
# Index              int64
# User Id           object
# First Name        object
# Last Name         object
# Gender            object
# Email             object
# Phone            float64
# Date of birth     object
# Job Title         object
# Salary             int64
# dtype: object

# %%
#8.Perform the following tasks using people dataset:
  #a)Read the data.cs file using pandas, skipping the first 50 rows.
  #b)Only read the columns: 'Last Name', 'Gender', 'Email', 'Phone' and 'Salary' from the file.
  #c)Display the first 10 rows of the filtered dataset.
  #d)Extract the 'Salary" column as a Series and display its last 5 values.

#Answer 8:

import pandas as pd

# a) Read the data.csv file using pandas, skipping the first 50 rows
url = 'https://drive.google.com/uc?id=13x8f8HNKieSRAzxTIzAojaYp8Up8cefk'
data = pd.read_csv(url, skiprows=50)

# b) Only read the specified columns: 'Last Name', 'Gender', 'Email', 'Phone', and 'Salary'
filtered_data = data[['Last Name', 'Gender', 'Email', 'Phone', 'Salary']]

# c) Display the first 10 rows of the filtered dataset
print("First 10 rows of the filtered dataset:")
print(filtered_data.head(10))

# d) Extract the 'Salary' column as a Series and display its last 5 values
salary_series = filtered_data['Salary']
print("\nLast 5 values of the 'Salary' column:")
print(salary_series.tail(5))

# %%
#9.Filter and select rows from the People_Dataset, where the "Last Name' column contains the name 'Duke, 'Gender' column contains the word Female and 'Salary' should be less than 85000.

#Answer 9:

import pandas as pd

file_path = 'path/to/your/People_Dataset.csv'
data = pd.read_csv(file_path)

filtered_data = data[
    (data['Last Name'].str.contains('Duke', na=False)) &
    (data['Gender'].str.contains('Female', na=False)) &
    (data['Salary'] < 85000)
]

print(filtered_data)

# %%
#10. Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6?

#Answer 10:

import pandas as pd
import numpy as np

# Generate 35 random integers between 1 and 6
random_integers = np.random.randint(1, 7, size=35)

# Create a DataFrame from the random integers
df = pd.DataFrame(random_integers.reshape(7, 5), columns=[f'Col_{i+1}' for i in range(5)])

# Display the DataFrame
print(df)
# Out:
#    Col_1  Col_2  Col_3  Col_4  Col_5
# 0      4      5      1      5      6
# 1      1      3      3      6      4
# 2      6      3      3      3      4
# 3      4      5      5      4      4
# 4      5      5      2      3      4
# 5      3      2      2      5      6
# 6      6      5      1      6      2

# %%
#11. Create two different Series, each of length 50, with the following criteria:
    #a) The first Series should contain random numbers ranging from 10 to 50.
    #b) The second Series should contain random numbers ranging from 100 to 1000.
    #c) Create a DataFrame by joining these Series by column, and, change the names of the columns to 'coll, 'col2. etc.

#Answer 11:

import pandas as pd
import numpy as np

# Create the first Series with random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, size=50))

# Create the second Series with random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, size=50))

# Create a DataFrame by joining the Series
df = pd.DataFrame({
    'col1': series1,
    'col2': series2
})

# Display the DataFrame
print(df)
# Out:
#     col1  col2
# 0     45   869
# 1     32   233
# 2     13   217
# 3     28   914
# 4     11   388
# 5     10   599
# 6     15   429
# 7     20   425
# 8     33   357
# 9     42   966
# 10    16   477
# 11    27   660
# 12    13   665
# 13    34   678
# 14    14   190
# 15    42   794
# 16    21   824
# 17    17   707
# 18    21   812
# 19    22   427
# 20    34   753
# 21    46   928
# 22    21   333
# 23    44   811
# 24    29   408
# 25    14   386
# 26    44   637
# 27    20   664
# 28    19   569
# 29    25   936
# 30    46   455
# 31    29   248
# 32    41   201
# 33    10   893
# 34    18   778
# 35    18   799
# 36    21   992
# 37    15   937
# 38    17   155
# 39    45   588
# 40    48   336
# 41    15   184
# 42    49   714
# 43    25   120
# 44    42   482
# 45    11   243
# 46    23   165
# 47    37   646
# 48    25   764
# 49    42   878

# %%
#12.Perform the following operations using people data set:
   #a)Delete the 'Email, 'Phone', and 'Date of birth' columns from the dataset.
   #b)Delete the rows containing any missing values.
   #c)Print the final output also.

#Answer 12:

import pandas as pd

# Load the dataset
file_path = 'path/to/your/People_Dataset.csv'  # Update with the correct path
data = pd.read_csv(file_path)

# a) Delete the 'Email', 'Phone', and 'Date of birth' columns
data = data.drop(columns=['Email', 'Phone', 'Date of birth'])

# b) Delete the rows containing any missing values
data = data.dropna()

# c) Print the final output
print(data)

# %%
#13.Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:
   #a)Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o.
   #b)Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5.
   #c)Add a vertical line at x = 0.5 using a dotted line style and label it as x = 0.5.
   #d)Label the x-axis as 'X-axis and the y-axis as Y-axis.
   #e)Set the title of the plot as Advanced Scatter Plot of Random Values.
   #f)Display a legend for the scatter plot, the horizontal line, and the vertical line.

#Answer 13:

import numpy as np
import matplotlib.pyplot as plt

# Create two NumPy arrays with 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# a) Create a scatter plot
plt.scatter(x, y, color='red', marker='o', label='Data Points')

# b) Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# c) Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# d) Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# e) Set the title of the plot
plt.title('Advanced Scatter Plot of Random Values')

# f) Display the legend
plt.legend()

# Show the plot
plt.show()

# %%
#14.Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity and Perform the following tasks using Matplotlib:
    #a)Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for Temperature and right y-axis for Humidity').
    #b)Label the x-axis as 'Date'.
    #c)Set the title of the plot as 'Temperature and Humidity Over Time'.

#Answer 14:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a time-series dataset
dates = pd.date_range(start='2023-01-01', periods=100)
temperature = np.random.uniform(low=15, high=30, size=100)  # Random temperatures between 15 and 30
humidity = np.random.uniform(low=30, high=100, size=100)     # Random humidity between 30 and 100

# Create a DataFrame
df = pd.DataFrame({
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity
})

# Plotting
fig, ax1 = plt.subplots()

# a) Plot Temperature on the left y-axis
ax1.plot(df['Date'], df['Temperature'], color='red', label='Temperature')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='red')
ax1.tick_params(axis='y', labelcolor='red')

# Create a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.plot(df['Date'], df['Humidity'], color='blue', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# b) Label the x-axis
ax1.set_xlabel('Date')

# c) Set the title of the plot
plt.title('Temperature and Humidity Over Time')

# Show the plot
plt.show()

# %%
#15.Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib:
  #a)Plot a histogram of the data with 30 bins.
  #b)Overlay a line plot representing the normal distribution's probability density function (PDF).
  #c)Label the x-axis as Value and the y-axis as Frequency/Probability.
  #d)Set the title of the plot as Histogram with PDF Overlay.

#Answer 15:

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Create a NumPy array containing 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)  # mean=0, std=1

# a) Plot a histogram of the data with 30 bins
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# b) Overlay a line plot representing the normal distribution's PDF
# Create an array of x values for the PDF
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, loc=0, scale=1)  # Calculate the PDF for the normal distribution

plt.plot(x, pdf, color='red', label='PDF', linewidth=2)

# c) Label the x-axis and y-axis
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# d) Set the title of the plot
plt.title('Histogram with PDF Overlay')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
#16.Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot’.

#Answer 16:

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate two random arrays
np.random.seed(0)  # For reproducibility
x = np.random.rand(100) * 10  # Random values between 0 and 10
y = np.random.rand(100) * 10  # Random values between 0 and 10

# Create a DataFrame
data = pd.DataFrame({'X': x, 'Y': y})

# Determine the quadrant
def get_quadrant(row):
    if row['X'] >= 5 and row['Y'] >= 5:
        return 'Quadrant 1'
    elif row['X'] < 5 and row['Y'] >= 5:
        return 'Quadrant 2'
    elif row['X'] < 5 and row['Y'] < 5:
        return 'Quadrant 3'
    else:
        return 'Quadrant 4'

data['Quadrant'] = data.apply(get_quadrant, axis=1)

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='X', y='Y', hue='Quadrant', palette='viridis', style='Quadrant', markers=['o', 's', 'D', 'X'])

# Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set the title of the plot
plt.title('Quadrant-wise Scatter Plot')

# Show legend
plt.legend(title='Quadrants')

# Show the plot
plt.show()

# %%
#17.With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'.

#Answer 17:

from bokeh.plotting import figure, show
import numpy as np

# Generate data for the sine wave
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Create a Bokeh figure
p = figure(title='Sine Wave Function', x_axis_label='X', y_axis_label='sin(X)',
           plot_width=800, plot_height=400)

# Add a line renderer
p.line(x, y, legend_label='sin(x)', line_width=2, line_color='blue')

# Add grid lines
p.grid.grid_line_alpha = 0.5

# Show the plot
show(p)

# %%
#18.Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart'.

#Answer 18:

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
import numpy as np
import pandas as pd

# Prepare the output to be displayed in a notebook
output_notebook()

# Generate random categorical data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 100, size=len(categories))

# Create a DataFrame for better handling
data = pd.DataFrame({'Category': categories, 'Value': values})

# Create a ColumnDataSource
source = ColumnDataSource(data)

# Create a Bokeh figure
p = figure(x_range=categories, title='Random Categorical Bar Chart',
           x_axis_label='Categories', y_axis_label='Values', plot_height=400)

# Add a bar renderer
bars = p.vbar(x='Category', top='Value', source=source, width=0.6,
              line_color='white', fill_color=factor_cmap('Value', palette='Spectral11', factors=values))

# Add hover tooltips
hover = HoverTool()
hover.tooltips = [("Category", "@Category"), ("Value", "@Value")]
p.add_tools(hover)

# Show the plot
show(p)

# %%
#19.Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'.

#Answer 19:

import plotly.graph_objects as go
import numpy as np

# Generate random data
np.random.seed(0)  # For reproducibility
x = np.linspace(0, 10, 100)  # 100 points from 0 to 10
y = np.random.rand(100)  # Random values

# Create a line plot
fig = go.Figure()

fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

# Label the axes
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#20.Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart.

#Answer 20:

import plotly.graph_objects as go
import numpy as np

# Generate random data
np.random.seed(0)  # For reproducibility
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(1, 100, size=len(labels))

# Create a pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values,
                               textinfo='label+percent',
                               hoverinfo='label+percent',
                               title='Interactive Pie Chart')])

# Update layout for title
fig.update_layout(title_text='Interactive Pie Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
